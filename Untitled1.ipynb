# %% [markdown]
# <a href="https://colab.research.google.com/github/lello227/lello/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installazione delle librerie necessarie
# !pip install roboflow
# !pip install torch torchvision torchaudio
# !pip install matplotlib

# Importazione delle librerie
from roboflow import Roboflow
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Carica il tuo dataset da Roboflow
# Sostituisci con il tuo API key
rf = Roboflow(api_key="pF052hZCR81XbjTA65D7")

# Carica il progetto e il dataset specifico
project = rf.workspace().project("saldature-difetti")
dataset = project.version(19).download("yolov11")  # Versione 1 del dataset

# Cloniamo il repository YOLOv5
# !git clone https://github.com/ultralytics/yolov11
# %cd yolov11

# Installiamo le dipendenze richieste
# !pip install -r requirements.txt

# Avvio dell'addestramento del modello YOLOv5
# !python train.py --img 640 --batch 16 --epochs 10 --data {dataset.location}/data.yaml --weights yolov11s.pt --cache

# Test del modello addestrato su nuove immagini
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --source {dataset.location}/test/images

# Visualizzazione dei risultati
# Sostituisci 'your_image.jpg' con il nome dell'immagine da visualizzare
img = mpimg.imread('runs/detect/exp/your_image.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 16.7 MB/s eta 0:00:00
# ...
